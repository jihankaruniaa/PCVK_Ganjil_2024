# %% [markdown]
# <a href="https://colab.research.google.com/github/jihankaruniaa/PCVK_Ganjil_2024/blob/main/Modul_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PRAKTIKUM

# %% [markdown]
# #### 1. Import folder yang ada di Drive Anda dengan cara sebagai berikut.

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
#   Pada kode program di bawah file image dengan nama kitten.jpg akan dibuka untuk diproses lebih lanjut.
#
#   Hasilnya berupa output gambar yang sudah di plot dengan matplotib untuk mengetahui ukuran panjang dan lebar dari gambar tersebut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/Image/kitten.jpg')
plt.imshow(img)

# %% [markdown]
# #### 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red. Tampilkan nilai pixel dan imag

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# #### 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/Image/kitten.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
#   Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
#   Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
#   Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
#   Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# Simpan file image
# cv.imwrite('/content/drive/MyDrive/SEMESTER 5/PCVK/Image/kitten.jpg', img5)

# Tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# #### 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
#   Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
# Perhatikan koordinat titik2 py1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
#   Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
#   Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %% [markdown]
#   Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %% [markdown]
#   Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
#   Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2))
# Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ## PERTANYAAN

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# - Jawab :
#
#   Gambar yang ditampilkan tanpa matplotlib biasanya menggunakan OpenCV. Perbedaan utama terdapat dalam format warna dan fitur tampilan. OpenCV menampilkan gambar dalam format BGR dan memiliki tampilan minimal, cocok untuk keperluan visualisasi cepat tanpa banyak kontrol tambahan. Sebaliknya, Matplotlib menampilkan gambar dalam format RGB dan menyediakan fitur tambahan seperti kontrol sumbu, zooming, panning, serta opsi untuk menambahkan label dan anotasi.

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# - Jawab :
#
#   Pembuatan gambar hitam menggunakan tipe data int16 dan int32 berbeda dalam hal rentang nilai dan penggunaan memori. Tipe data int16 memiliki rentang nilai dari -32,768 hingga 32,767, sedangkan int32 memiliki rentang yang jauh lebih besar, yaitu dari -2,147,483,648 hingga 2,147,483,647.

# %% [markdown]
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
#   ![image.png](data:image/png;base64,...)
#
# - Jawab :
#
#   from google.colab.patches import cv2_imshow, digunakan di Google Colab untuk menampilkan gambar yang diproses dengan OpenCV secara langsung dalam notebook. Fungsi ini merupakan pengganti dari cv2.imshow, yang tidak dapat digunakan di lingkungan notebook seperti Colab karena tidak mendukung tampilan jendela GUI.

# %% [markdown]
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
# - Jawab :
#
#   from skimage import io, memungkinkan pembacaan dan pemrosesan gambar dengan menggunakan berbagai format file, menyimpan gambar sebagai array NumPy yang dapat digunakan dalam analisis lebih lanjut.

# %% [markdown]
# ## TUGAS

# %% [markdown]
# 1.  Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image disarankan menggunakan bilangan acak/random!

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %% [markdown]
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.
